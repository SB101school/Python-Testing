# %%
On = True;
import random;
import time;

def DnDTools():
    print("Which tool");
    Options = ["Dice Roll", "Name", "Ability Name", "Item Name", "Nevermind"];
    for i in range(len(Options)):
        print(i, Options[i]);
    Input = input();
    if(Input == "0" or
        Input == "Dice Roll" or
        Input == "dice Roll" or
        Input == "dice roll" or
        Input == "dice" or
        Input == "Dice" or
        Input == "roll" or
        Input == "Roll"):
            print("How Many? /(/enter a number value/)/ ");
            Input2 = input();
            numberofdice = Input2;
            print("What Die?");
            Options = ["d4", "d6", "d8", "d10", "d12", "d20", "d100"];
            for i in range(len(Options[i])):
                print(i, Options[i]);
            Input3 = input();
            if(Input3 == "d4" or Input3 == "D4"):
                print("1");
            elif(Input3 == "d8" or Input3 == "D8"):
                print("1");
            elif(Input3 == "d10" or Input3 == "D10"):
                print("1");
            elif(Input3 == "d12" or Input3 == "D12"):
                print("1");
            elif(Input3 == "d20" or  Input3 == "D20"):
                print("1");
            elif(Input3 == "d100" or Input3 == "D100"):
                print("1");
            elif(Input3 == "d6" or Input3 == "D6"):
                
            else:
                print("Invalid Input");
        

while(On):
    print("What do you need?");
    Options = ["DnD Tools", "Art Tools", "Entertainment", "Calculator", "Nothing"];
    for i in range(len(Options)):
        print(i, Options[i]);
    Input = input();
    if(Input == "4" or 
        Input == "Nothing" or
        Input == "nothing"): On = False;
    if(Input == "0" or
        Input == "DnD" or
        Input == "dnd"): 
            DnDTools();
